# %%
# first time run to filter and refactor the data
# %run 01_correlation_analysis.py # training.csv (10214 features)
# %run 02_data_preprocessing.py # training_filtered.csv (3579 features)

# %%
# second time run to filter and refactor the data
# %run 01_correlation_analysis.py # training_filtered.csv (3579 features)
# %run 02_data_preprocessing.py # training_filtered_refined.csv (2911 features)

# %%
# third time run to filter and refactor the data
# %run 01_correlation_analysis.py # training_filtered.csv (2911 features)
# %run 02_data_preprocessing.py # training_filtered_refined.csv (2673 features)

# %%
# %run 03_merge_column.py

# %%
# %run 04_training.py

# %%
# %run 06_trans_test..py
# %run 03_merge_column.py

# %%
# %run 05_inference.py
